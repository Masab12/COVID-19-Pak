# %%
import pandas as pd
import numpy as np
import matplotlib as pyplt

# %%
df=pd.read_csv("COVID-19Pakistan.csv")

# %%
df
# Out:
#     Country            Region     Last Update  Confirmed  Deaths
# 0  Pakistan            Punjab  1/22/2020 1:00        152       0
# 1  Pakistan               KPK  1/22/2020 1:00         31       2
# 2  Pakistan       Balochistan  1/22/2020 1:00        103       0
# 3  Pakistan            Fedral  1/22/2020 1:00         10       0
# 4  Pakistan               AJK  1/22/2020 1:00          1       0
# 5  Pakistan             Sindh  1/22/2020 1:00        292       1
# 6  Pakistan  Gilgit-Baltistan  1/22/2020 1:00         55       0

# %%
df.plot(kind='bar',x='Region',y='Confirmed')

# %%
df.plot(kind='line',x='Region',y='Confirmed')
df.plot(kind='line',x='Region',y='Deaths', color='red')
